# %% [markdown]
# # Observatory

# %% [markdown]
# ## JoinMarket analysis crosschecking

# %% [markdown]
# Adam Gibson (AKA waxwing), one of the lead maintainer of JoinMarket, published an analysis (here: https://x0f.org/@waxwing/106210642377163192) of roughly 1.3 days of JoinMarket activity (from block `682603` to block `682795`), the same analysis is repeated in this example as crosschecking.
# Waxwing removed some false positives by hand, which is not done here, also because I'm not sure what process he followed.
# The result are nonetheless very similar.

# %% [markdown]
# ## Menu

# %% [markdown]
# **Setup**
#
# * [Create new dataframe](#Crate-new-dataframe)
# * [Save dataframe](#Save-dataframe)
# * [Load dataframe](#Load-existing-dataframe)
#
# **Analysis**
#
# * [Glimpse](#Glimpse)
# * [Stats](#Stats)
# * [Transaction explorer](#Transaction-explorer)
# * [Plot](#Plot)
# * [Volume](#Volume)
# * [Daily](#Daily)
#
# **Advanced**
#
# * [Advanced creation](#Advanced-creation)

# %% [markdown]
# ---

# %% [markdown]
# ## Create new dataframe

# %% [markdown]
# Insert in the cell below the `start` block height and the `end` block height, select your desired filter and run it to create the dataframe.
#
# **Example:**
#
# `start = 100`
# `end = 200`
#
# Will search for transactions between block 100 and block 200 included.
#
# You can also give **negative** values to `start` and this will scan the last chosen blocks **depending** on the `end` value.
#
# **Example:**
#
# `start = -10`
# `end = 0`
#
# Will search for transactions in the last 10 blocks.
#
# **Example:**
#
# `start = -10`
# `end = 5`
#
# Will search for transanction in 5 block starting from ten blocks ago.

# %%
import observatory as obs
import advanced.filters as filters


### INSERT HERE ###
start = 682603
end = 682795
txid = ''
address = ''


### CHOOSE ONE OF THE FILTERS BELOW BY REMOVING THE '#' IN FRONT OF IT ###
#tx_filter = filters.TxFilter() # This will return every transaction
#tx_filter = filters.CjFilter()
#tx_filter = filters.WasabiFilter()
tx_filter = filters.JoinmarketFilter()
#tx_filter = filters.TxidFilter(txid) # If you pick me, don't forget to insert a 'txid' above.
#tx_filter = filters.AddressFilter(address) # If you pick me, don't forget to insert an 'address' above.
#tx_filter = filters.CoinbaseFilter()

txs = await obs.create_dataframe(start, end, tx_filter)
# Out:
# Start scanning from block **682603** to block **682795** included...
# 193it [03:25,  1.07s/it]
# Created dataframe of **77** transactions in 206.26s
# [Save dataframe](#Save-dataframe)
# [Start analysis](#Glimpse)

# %% [markdown]
# [Back to menu](#Menu)
#
# ---

# %% [markdown]
# ## Save dataframe

# %% [markdown]
# Insert the **filepath** where to save and run the cell.
#
# **Examples:**
#
# `filepath = 'thisfilename'`
# `filepath = '/home/thisfilename'`
# `filepath = 'results/wasabi/thisfilename'`
#
# Will create a `thisfilename.ftr` file into the given filepath.

# %%
### INSERT HERE ###
filepath = 'results/mydataframe'


obs.save(filepath, txs)

# %% [markdown]
# [Back to menu](#Menu)
#
# ---

# %% [markdown]
# ## Load existing dataframe

# %% [markdown]
# Insert the **filepath** of the dataframe to load and run the cell.
#
# **Examples:**
#
# `filepath = 'thisfilename'`
# `filepath = '/home/thisfilename'`
# `filepath = 'results/mytxs/thisfilename'`
#
# Will load the `thisfilename.ftr` file from the given filepath.

# %%
import observatory as obs


### INSERT HERE ###
filepath = 'results/mydataframe'


txs = obs.load(filepath)

# %% [markdown]
# [Back to menu](#Menu)
#
# ---

# %% [markdown]
# ## Glimpse

# %% [markdown]
# Run the cell below for a glimpse of the dataframe.
#
# You can change the `n_txs` value to specify how many transactions to display.
# You can also give `n_txs` a **negative** value to display the last n transactions.
#
# You can insert the `sort_by` value to specify which column should give the ordering. e.g. 'n_eq', 'date', etc... Default is 'date'.

# %%
### INSERT HERE ###
n_txs = 100
sort_by = ''


obs.show_intro(txs, n_txs, sort_by)
# Out:
# **77 total transactions**
#                                                     version   size  vsize  \
# txid
# 678a07d7895dc25d9f132bf54cbff21b9a670cd86d1e54b...        1   3031   1822
# 1855914456c48b910e9fbbb5677535fd4a0f407bb341b4c...        2   1423    858
# e18710a9f5361ed591e30959d3e91b3ce33ae64f15db29d...        1   1597   1031
# bdd7a44eadfb9545a929545b5b44879261a13582ba9477e...        1   1936   1212
# 38de2163eb8997ecc2247432cfd42da4d6715c42d815dfd...        2   3000   1629
# b6c924f860e15392ccb87ecafef09b18cb00202bfe1c66b...        1   1363    877
# 1542068f6e5cd6a559e2c13c7c48d270074f6a621a13f1c...        2   1065    660
# f5d970ec48a9f6773eed5bd9d5b3d914124513d5f238b87...        2   1003    598
# 767abf94b4137fa6ab87c8e181f80f2853f557f4761f533...        2   1182    697
# fe1a0d76ea6c4719faf2766ed21842f7b101d8d8281dece...        2   2623   1489
# c7dad02623f50a7cb975c34257f223dbbcbff93f4dc1466...        2   2352   1383
# b8590123501a0cd395ca86a88f18b915db33516ca3f4182...        2   1633    988
# 788c0a0395eeefa86e3ec57a6d084a986fc604580d9241e...        2   3009   1717
# c1261fb8020921b742d90e62668d910eceaed7d01f8a2c4...        2   1777    969
# c8319e0fc68f1f773d173eaa6cf9302ed37e8cfcca05a7d...        2   2206   1316
# 93990266be4419142f930992afab258295b2dffcacdb26f...        1   2220   1331
# 8c8f34ace311c790238f18c3ebc7c1e9ad353dec0298e44...        2   3459   2007
# 008d3e0a150a416ed01505bb425f2a76c66373a2a0408ab...        1   1531    967
# 7b6aa06d63b542de07f96e30e8629a40da6f06dfaad3d5e...        2   5149   2729
# 5ff3319ad8168688d2410e7caabc8b0d708f4c8fe63f6d3...        2   2117   1310
# 9ba8b9050a79a14e9bdf1c9fa89cbf17d4b0fd48a98a4a1...        1  66022  28153
# 18e850304344fdc54402b8a89f38980283474c4715002aa...        1   1502    935
# 7903dcfc74647e5a5ec80b0d28dc0f7c20f59674e63ca25...        2   2203   1315
# 13189742ab1b95954e6b0c41eaab55f30045ee198bfa5b6...        2   4454   2277
# 0d8adee52059c954f7eeb6371ac24959837af97da23d844...        2   2440   1390
# f264a5022b71d9545230ebc88ff5fa25efa6214505751e1...        1   1768   1122
# 86cb5f22a29b6aebd1ea54159aa3062b6671d4cb16e73e7...        1   2280   1394
# 2ac3443f67baef3fd27d5a7ff34dfe513552e5a6d7f3c01...        2   1573    926
# 6f7bfbd0e75100dbcb0259f9c129503126792b6782569f9...        2   2520   1308
# 9e9b933e8734a51e31f8a7e75964903cad0031cd477a67f...        2   1498    932
# b2c9f6e2baf3bd9beebf07ef007d1b86aa220b2e6541e13... 2021-05-09 17:08:00
# 7c37f048a8ac887d1d4c71650e61814612166f9f18e24d6... 2021-05-09 17:28:00
# 7c539c8054e3456890bbde598548082912926f0edaa0e95... 2021-05-09 17:34:00
# 8b1306da71059b1d4590895cd4d60b84216bc673525bd53... 2021-05-09 17:35:00
# 85ebd0f2e2f5f5da77c75e8bd8b753fe311dbb935ab82ec... 2021-05-09 17:35:00

# %% [markdown]
# [Back to menu](#Menu)
#
# ---

# %% [markdown]
# ## Stats

# %% [markdown]
# Run the cell below for a list of statistics about the dataframe.

# %%
obs.show_stats(txs)
# Out:
#          version          size         vsize         weight       locktime  \
# count  77.000000     77.000000     77.000000      77.000000      77.000000
# mean    1.675325   5137.246753   2537.246753   10147.558442  461038.961039
# std     0.471324  12413.080881   5235.062442   20940.340893  321769.245741
# min     1.000000   1003.000000    598.000000    2392.000000       0.000000
# 25%     1.000000   1688.000000    988.000000    3949.000000       0.000000
# 50%     2.000000   2493.000000   1390.000000    5557.000000  682648.000000
# 75%     2.000000   3238.000000   1789.000000    7156.000000  682719.000000
# max     2.000000  66033.000000  28156.000000  112623.000000  682793.000000
#
#              n_in      n_out       n_eq           den        abs_fee  \
# count   77.000000  77.000000  77.000000  7.700000e+01      77.000000
# mean    21.727273  13.233766   6.831169  1.598381e+08   49846.922078
# std     37.132280   4.211188   2.098888  2.815094e+08   63252.266015
# min      5.000000   5.000000   3.000000  1.110000e+05    1515.000000
# 25%      8.000000  10.000000   5.000000  1.021729e+07    6997.000000
# 50%     14.000000  13.000000   7.000000  6.696166e+07   24408.000000
# 75%     17.000000  16.000000   8.000000  1.632175e+08   80594.000000
# max    200.000000  25.000000  13.000000  1.417682e+09  383378.000000
#
#           rel_fee         height
# count   77.000000      77.000000
# mean    31.584416  682707.480519
# std     36.981628      58.089226
# min      1.000000  682603.000000
# 25%      4.000000  682651.000000
# 50%     12.000000  682715.000000
# 75%     56.000000  682757.000000
# max    144.000000  682795.000000

# %% [markdown]
# [Back to menu](#Menu)
#
# ---

# %% [markdown]
# ## Transaction explorer

# %% [markdown]
# Run the cell below to display information about single transactions.
#
# If you set `display_all = True` the result will include every input and every output.
# If the transaction is huge, or you are looking at more than one transanction. this could be slow or even freeze your browser.

# %%
### INSERT HERE ###
txid = 'a7e0f6399646f8faa5a125f2141fe64e79c865ede7942bf2a6b5ce174268b0f6'
display_all = False

obs.show_tx(txs, txid, display_all)
# Out:
#                                                                   version  \
# txid
# a7e0f6399646f8faa5a125f2141fe64e79c865ede7942bf2a6b5ce174268b0f6        2
#
#                                                                   size  vsize  \
# txid
# a7e0f6399646f8faa5a125f2141fe64e79c865ede7942bf2a6b5ce174268b0f6  4349   2414
#
#                                                                   weight  \
# txid
# a7e0f6399646f8faa5a125f2141fe64e79c865ede7942bf2a6b5ce174268b0f6    9656
#
#                                                                   locktime  \
# txid
# a7e0f6399646f8faa5a125f2141fe64e79c865ede7942bf2a6b5ce174268b0f6    682718
#
#                                                                   n_in  n_out  \
# txid
# a7e0f6399646f8faa5a125f2141fe64e79c865ede7942bf2a6b5ce174268b0f6    24     25
#
#                                                                   n_eq  \
# txid
# a7e0f6399646f8faa5a125f2141fe64e79c865ede7942bf2a6b5ce174268b0f6    13
#
#                                                                       den  \
# txid
# a7e0f6399646f8faa5a125f2141fe64e79c865ede7942bf2a6b5ce174268b0f6  5601098
#
#                                                                   abs_fee  \
# txid
# a7e0f6399646f8faa5a125f2141fe64e79c865ede7942bf2a6b5ce174268b0f6    13981
#
#                                                                   rel_fee  \
# txid
# a7e0f6399646f8faa5a125f2141fe64e79c865ede7942bf2a6b5ce174268b0f6        5
#
#                                                                   height  \
# txid
# a7e0f6399646f8faa5a125f2141fe64e79c865ede7942bf2a6b5ce174268b0f6  682720
#
#                                                                                 date
# txid
# a7e0f6399646f8faa5a125f2141fe64e79c865ede7942bf2a6b5ce174268b0f6 2021-05-09 09:16:00
# ### Inputs
#                                                                 txid  height  \
# 0   c1261fb8020921b742d90e62668d910eceaed7d01f8a2c4df4f10477bcbe3a8c  682631
# 1   f21f64a3dbca114331c9584f309b903ee978b00550e3611eadb8b48c5d9dd2c8  668432
# 8     4837323     9  [bc1qfuwtz9fewashme8dzpd25glzc5puaqr0wlq7ym]
# 9     2944069     1  [bc1qgcz8du76led0hpwf2z62gxv9207crm2rlpghvh]
# 10    7029952    16  [bc1qx7wtnqqpka3qx5l333s8j2vjdtezqexmvjamqn]
# 11    3197536     1  [bc1qdvamvh3yuhxl7j380t0m2jhmpmfnh6uctxxe3j]
# 12    3133318    13  [bc1qh74yt2hakjp7wqzegxadg8qtcf4hmmj48ucfln]
# 13    7044936    10  [bc1qlq35jz05qqvx59l287rrzzmcjl9gupfv3f3azm]
# 14   31936480     3  [bc1q60s98e7926xrt2qsklqggf0d3nwkx7f4xkhrz9]
# 15     415137    13  [bc1qe0fu8rhpmuzvnxauzjueqg39g5kvpvzca0smgu]
# 16    2671704     2  [bc1q5f4thmql8unkwsslpp96kpe7z8zglp6ujcvrn8]
# 17    3400000    23  [bc1qwqlajh6qz72uw2y7rws249e4h2hx4j5ujgp9wg]
# 18   16270275    13  [bc1q7w2xrnykcesejqqapx6tc5da60jt2p8umwpsc6]
# 19     342332    12  [bc1qwe48e3utkt6nmqplyckfft4c7f4wsppk5tkcj4]
# 20    3634999     5  [bc1q2gqh644tvktnr3rwrsmq577z4lnxld0jd869gy]
# 21    1046977     9  [bc1q040p2zcn6kertyu857ellajduejr95zptxzf4r]
# 22   45245946     4  [bc1qnuefxlyqjrsgzj3mltzftqgpmx0nge2yr69mye]
# 23     467595     7  [bc1qz8r2r869uwzpq6xxn8hzvkg579zlv7v9tw5qc5]
#
#                   type  available
# 0   witness_v0_keyhash       True
# 1   witness_v0_keyhash      False
# 2   witness_v0_keyhash      False
# 3   witness_v0_keyhash      False
# 4   witness_v0_keyhash      False
# 5   witness_v0_keyhash      False
# 6   witness_v0_keyhash      False
# 7   witness_v0_keyhash      False
# 8   witness_v0_keyhash      False
# 9   witness_v0_keyhash      False
# 10  witness_v0_keyhash       True
# 11  witness_v0_keyhash      False
# 12  witness_v0_keyhash      False
# 13  witness_v0_keyhash      False
# 14  witness_v0_keyhash       True
# 15  witness_v0_keyhash      False
# 16  witness_v0_keyhash      False
# 17  witness_v0_keyhash      False
# 18  witness_v0_keyhash       True
# 19  witness_v0_keyhash      False
# 20  witness_v0_keyhash      False
# 21  witness_v0_keyhash      False
# 22  witness_v0_keyhash       True
# 23  witness_v0_keyhash      False
# ### Outputs
#           value                                     addresses  \
# vout
# 0       5601098  [bc1qq9nre473xl7tmkqa02lrw303ruxpvtxp73ut48]
# 1         97531  [bc1qyffwutg49g4nucedvm7trd33v2nlt6d0csfdj8]
# 2       1666863  [bc1qpvq7x538gllrdtnzlzqv9xwaah72qjexcpp7uc]
# 3       5601098  [bc1qruww57cqrz58uy7fdrdt3cc6vwjqs7r9nruu0c]
# 4       5601098  [bc1q9tdhv74chjn87v0hv27fn3m8v4zy5k3v0xc9y0]
# 5       1167276  [bc1qn9e9fpc7qfdw8dxqc720xukze4yerjuscsqs7r]
# 6       5601098  [bc1qphtva5ktmzfak6f75lvc7ucjxkz8m4p35tr7ww]
# 7     139868484  [bc1q7ulhs67shwzxmadx52z47jqdzj88pjrgnktyyg]
# 8       5601098  [bc1q2sd39sxvck3lrur9znm0n6664tc8cdjv3a3j3a]
# 9      10669295  [bc1qrsjae5cswhwxsqyr83nl8cv350n5fct5h3avqf]
# 10      5601098  [bc1q87seq6fmjxl0lmllzdvv70sxamxy45yt5ceatu]
# 11     26335494  [bc1qkqh8l5tvce3mcrn2uzuqnf7mas94fykt3wk23h]
# 12      5601098  [bc1qpsj2p83sl6mkfegauddfxsd87x0chqlfq9ca6x]
# 13      4873912  [bc1q4phhy0mf07e9havkpkgrul2rdw5cfe768p2gsq]
# 14      5601098  [bc1q4zvjpdglaf90trnpkhg5243hxafwk3tkxz8zff]
# 15     39644876  [bc1qv4fxrma25wychsr6060tx28d582kkhjuz7k4ys]
# 16      1428899  [bc1q64rfvcmkaf2umraek6aaffpw2j3astee2qgrzs]
# 17      1328908  [bc1qdzxdqkkjjl3ga06nls3y03sw32pvjh4sh9jgzm]
# 18        46275  [bc1qhw4z9aysdae94v6q6aykvwv3t2e26nuwjddr5x]
# 19      5601098  [bc1qqzch5cy2v5gqrhe8869agx66ctup7lx3fst89u]
# 20      5601098  [bc1qtu5vxna2p8q60ukgvsscn0esdyu4ck4k2wlc7u]
# 21      1443840  [bc1qtt2vuhk066wwcy3ppzjj74gjf6rknhx9972y6j]
# 22      5601098  [bc1qudx5lap3wrw63uhrm2l23szeqxa3509xyfwpw7]
# 23      5601098  [bc1qm5uh8khqadlxjcg460hg7ynm5k3kzqch6dn2d6]
# 24      5601098  [bc1qzapxaj0azlkyurld2rl39malf0jradw3xdpg5e]
#
#                     type
# vout
# 0     witness_v0_keyhash
# 1     witness_v0_keyhash
# 2     witness_v0_keyhash
# 3     witness_v0_keyhash
# 4     witness_v0_keyhash
# 5     witness_v0_keyhash
# 6     witness_v0_keyhash
# 7     witness_v0_keyhash
# 8     witness_v0_keyhash
# 9     witness_v0_keyhash
# 10    witness_v0_keyhash
# 11    witness_v0_keyhash
# 12    witness_v0_keyhash
# 13    witness_v0_keyhash
# 14    witness_v0_keyhash
# 15    witness_v0_keyhash
# 16    witness_v0_keyhash
# 17    witness_v0_keyhash
# 18    witness_v0_keyhash
# 19    witness_v0_keyhash
# 20    witness_v0_keyhash
# 21    witness_v0_keyhash
# 22    witness_v0_keyhash
# 23    witness_v0_keyhash
# 24    witness_v0_keyhash

# %% [markdown]
# [Back to menu](#Menu)
#
# ---

# %% [markdown]
# ## Plot

# %% [markdown]
# Run the cell below to plot the desired `column`.
#
# If you give it a `filepath`, the result graph will be saved.

# %%
### INSERT HERE ###
column = 'n_eq'
filepath = ''

obs.show_graph(txs, column, filepath)

# %% [markdown]
# [Back to menu](#Menu)
#
# ---

# %% [markdown]
# ## Volume

# %% [markdown]
# Run the cell below to show the volume graph.
#
# If you give it a filepath, the result graph will be saved.

# %%
filepath = ''

obs.show_volume(txs, filepath)
# Out:
# **Input** volume: 2615.97387717
# **Equal output** volume: 888.21563817

# %% [markdown]
# [Back to menu](#Menu)
#
# ---

# %% [markdown]
# ## Daily

# %% [markdown]
# Run the cell below to show the transanctions per day graph.
#
# If you give it a filepath, the result graph will be saved.

# %%
filepath = ''

obs.show_daily(txs, filepath)

# %% [markdown]
# [Back to menu](#Menu)
#
# ---

# %% [markdown]
# ## Advanced creation

# %% [markdown]
# Here you can create a dataframe using your own filters.
# You can also pass more than one filter and every transaction that matches at least one of them will be included in the dataframe.
# **Each and every** criteria has to be satisfied in order for a transaction to match a filter.
#
# Valid criteria are:
# * **txid**
#     * e.g., `txid='mytxid'` will scan for transactions that include 'mytxid' in the txid.
# * **address**
#     * e.g., `address='myaddress'` will scan for transactions that include 'myaddress' in at least one of the addresses. Accept multiple addresses (each and every of them has to be part in a transaction for the transaction to match the filter).
# * **in_type**
#     * e.g., `in_type='scripthash'` will scan for transactions that have all the inputs of type 'scripthash'.
# * **out_type**
#     * e.g., `out_type='scripthash'` will scan for transactions that have all the outputs of type 'scripthash'.
# * **version**
#     * e.g., `version=(minversion, maxversion)` will scan for transactions that have a version number between minversion and maxversion included.
# * **size**
#     * e.g., `size=(minsize, maxsize)` will scan for transactions that have a size between minsize and maxsize included.
# * **vsize**
#     * e.g., `vsize=(minvsize, maxvsize)` will scan for transactions that have a virtual size between minvsize and maxvsize included.
# * **weight**
#     * e.g., `weight=(minweight, maxweight)` will scan for transactions that have a weight between minweight and maxweight included.
# * **locktime**
#     * e.g., `locktime=(minlocktime, maxlocktime)` will scan for transactions that have a locktime between minlocktime and maxlocktime included.
# * **n_in**
#     * e.g., `n_in=(minn_in, maxn_in)` will scan for transactions that have a number of inputs between minn_in and maxn_in included.
# * **n_out**
#     * e.g., `n_out=(minn_out, maxn_out)` will scan for transactions that have a number of outputs between minn_out and maxn_out included.
# * **n_eq**
#     * e.g., `n_eq=(minn_eq, maxn_out)` will scan for transactions that have a number of equally sized outputs between minn_eq and maxn_out included.
# * **den**
#     * e.g., `den=(minden, maxden)` will scan for transactions that have a denomination between minden and maxden included.
# * **abs_fee**
#     * e.g., `abs_fee=(minabs_fee, maxabs_fee)` will scan for transactions that have an absolute fee between minabs_fee and maxabs_fee included.
# * **rel_fee**
#     * e.g., `rel_fee=(minrel_fee, maxrel_fee)` will scan for transactions that have a relative fee between minrel_fee and maxrel_fee included.
# * **height**
#     * e.g., `height=(minheight, maxheight)` will scan for transactions that have a height between minheight and maxheight included.
# * **date**
#     * e.g., `date=('2020-09-18', '2020-09-19 19:00')` will scan for transactions that have a date between mindate and maxdate included.
#
# You can also pass arbitrary callables as long as they accept a Tx object as parameter and return True or False.
# e.g., `callables=[mycallable]`
#
# Here's how a filter that searches for transactions that pay more than 100 sat/vbyte and have just 1 input and 1 output would look like.
#
# `tx_filter = filters.TxFilter(n_in=(1, 1), n_out=(1, 1), rel_fee=(100, 100000))`

# %%
import observatory as obs
import advanced.filters as filters


### INSERT HERE ###
start = -10
end = 0
tx_filter = filters.TxFilter(n_in=(1, 1), n_out=(1, 1), rel_fee=(100, 100000))


txs = await obs.create_dataframe(start, end, tx_filter)

# %% [markdown]
# [Back to menu](#Menu)
#
# ---
